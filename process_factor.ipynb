# %%
import pandas as pd
import os
from utils import *
from config import exclude_codes
import datetime
import statsmodels.api as sm
from scipy.optimize import minimize, LinearConstraint
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)
pd.set_option('display.min_rows', 100)
from statsmodels.stats.correlation_tools import cov_nearest
from calc_rets_and_cov import get_factor_rets, get_cov_date
from optimize import *

# %%
import importlib
import utils
importlib.reload(utils)
from utils import *

# %%
load_from_data = True

# %%
weights = fill_weights()
history = get_history_data()
market_cap = get_market_cap()
industry_stock = read_data('industry_stock.csv')
history = pd.merge(history.reset_index(), 
                   market_cap.reset_index(), 
                   how='left', 
                   left_on=['time', 'code'], 
                   right_on=['time', 'code']).set_index('time')
history['ret'] = history.groupby('code')['close'].pct_change(fill_method=None)
history.tail()
# Out:
#                    code  close  factor      volume  market_cap       ret
# time
# 2023-07-31  688981.XSHG  51.36     1.0  25944137.0   4070.7610  0.021886
# 2023-08-01  688981.XSHG  50.72     1.0  18110314.0   4020.0349 -0.012461
# 2023-08-02  688981.XSHG  50.83     1.0  10813980.0   4028.7534  0.002169
# 2023-08-03  688981.XSHG  50.91     1.0  12048176.0   4035.0942  0.001574
# 2023-08-04  688981.XSHG  51.10     1.0  17100810.0   4050.2263  0.003732

# %%
factor_folder = './data/factor'
factor_files = os.listdir(factor_folder)
factor_df_map = {}
for file in factor_files:
    df_temp = pd.read_csv(os.path.join('./data/factor', file), index_col=0)
    df_temp.fillna(method='ffill', limit=10, inplace=True)
    df_temp.index = pd.to_datetime(df_temp.index)
    factor_df_map[file[:-4]] = df_temp
    
norm_df_map = {}
for key, value in factor_df_map.items():
    norm_df_map[key] = get_normalized_factor(value, weights)    
    
norm_factor_exposure = pd.concat([value.stack(dropna=False).sort_index(level=1).rename(key) for key, value in norm_df_map.items()], axis=1)
norm_factor_exposure = norm_factor_exposure.reset_index(level=1).rename(columns={'level_1': 'code'})
norm_factor_exposure = norm_factor_exposure[norm_factor_exposure.index >= weights.index[0]]

# %%
factor_columns = ['country'] + list(norm_df_map.keys()) + industry_stock.stack().unique().tolist()
factor_rets = pd.DataFrame(index=history.index.unique(), columns=factor_columns)
rsquare_df = pd.Series(index=history.index.unique(), name='rsquare', dtype=float)
residual_rets = pd.DataFrame(index=history.index.unique(), columns=weights.columns)

if load_from_data:
    factor_rets = pd.read_csv('inter_data/factor_rets.csv', index_col=0, parse_dates=True)
    residual_rets = pd.read_csv('inter_data/residual_rets.csv', index_col=0, parse_dates=True)
else:
    dates = history.index.unique()
    dates = dates[dates >= weights.index.min()]

    dates_to_chek = []

    for i in range(0, len(dates)):
        date = dates[i]
        factor_temp, residual_temp, rsquare = get_factor_rets(date, history, weights, norm_df_map, industry_stock)
        factor_rets.loc[date, factor_temp.columns] = factor_temp.values
        residual_rets.loc[date, residual_temp.columns] = residual_temp.values
        rsquare_df.loc[date] = rsquare
        if np.isnan(rsquare):
            print(f'Warning: {date} has nan rsquare')
            dates_to_chek.append(date)
        
        if i % 300 == 0:        
            print(f'Finished the {date}, the rsquare is {rsquare:.2f}')
            
    factor_rets.to_csv('inter_data/factor_rets.csv')
    residual_rets.to_csv('inter_data/residual_rets.csv')

# %%
factor_cov = factor_rets.ewm(halflife=22, min_periods=5).cov(pairwise=True)
residual_vol = residual_rets.ewm(halflife=22, min_periods=5).std()

# %%
from statsmodels.regression.rolling import RollingOLS, RollingWLS

# get expected returns
if load_from_data:
    expected_rets_all = pd.read_csv('inter_data/expected_rets.csv', index_col=0, parse_dates=True)
else:
    short_time = 5
    long_time = 30
    ret_df = history.groupby('code')['ret']
    temp = ret_df.rolling(short_time, min_periods=3).sum() - ret_df.rolling(long_time, min_periods=long_time//2).sum()

    signal = temp.unstack(level=0)
    norm_signal = get_normalized_factor(signal, weights)
    norm_signal_lag = norm_signal.shift(2)
    history_ret = history.groupby('code')['ret']

    ret_fut = history[['code', 'ret']].pivot(columns='code', values='ret').shift(-2)

    expected_rets_all = pd.DataFrame(index=ret_fut.index, columns=ret_fut.columns)
    corr_all = []

    print(np.nanmean(norm_signal.corrwith(ret_fut)))
    for i in range(len(ret_fut.columns)):
        colname = ret_fut.columns[i]
        params = RollingWLS(ret_fut.iloc[:,i], 
                            sm.add_constant(norm_signal.iloc[:,i]), 
                            window=30, 
                            min_nobs=20, 
                            ).fit().params
        expected_rets = -(sm.add_constant(norm_signal.iloc[:,i].fillna(0)) * params.shift(2)).sum(axis=1, skipna=False)
        expected_rets_all.loc[:, colname] = expected_rets
        corr_temp = expected_rets.corr(ret_fut.iloc[:,i])
        print(colname, corr_temp)
        corr_all.append(corr_temp)
        
    expected_rets_all.to_csv('inter_data/expected_rets.csv')

# %%
np.nanmean(expected_rets_all.corrwith(ret_fut))
# Out:
# 0.010124602283565189

# %%
all_trading_dates = expected_rets_all.dropna(how='all').index
all_trading_dates = all_trading_dates[all_trading_dates >= '2006-04-27']
weights_optimize_df = pd.DataFrame(0.0, index=all_trading_dates, columns=weights.columns)

# %%
cvxopt.solvers.options['show_progress'] = False
model_type = 'cvxopt'
for date in weights_optimize_df.index[weights_optimize_df.sum(axis=1) == 0]:
    factor_cov_date, expected_rets, weight_target, nonzero_codes, tradable_codes, \
    added_stock, remove_stock, non_tradable_codes, date_index, previous_weight, index_weight = \
        prepare_data_for_optimization(date, 
                                  history,
                                  weights,
                                  weights_optimize_df,
                                  factor_cov,
                                  norm_factor_exposure,
                                  residual_vol,
                                  industry_stock,
                                  expected_rets_all)
    if len(remove_stock):
        weight_target += weights_optimize_df.iloc[date_index-1][remove_stock].sum()
        
    if model_type == 'cvxopt':
        if len(remove_stock) > 20:            
            result = optimize_portfolio_cvxopt(expected_rets, factor_cov_date, previous_weight.loc[tradable_codes], (index_weight/index_weight.sum()).loc[tradable_codes], 
                                        target_weight=weight_target, max_turnover=0.15 + weights_optimize_df.iloc[date_index-1][remove_stock].sum() / 2)
        else:
            result = optimize_portfolio_cvxopt(expected_rets, factor_cov_date, previous_weight.loc[tradable_codes], (index_weight/index_weight.sum()).loc[tradable_codes], 
                                    target_weight=weight_target)
        realized_sum = np.array(result['x'][:(len(result['x']) // 3)]).sum() + previous_weight.loc[non_tradable_codes].sum()
        status = result['status'] 
        minimize_value = result['primal objective']
                
    else:    
        if len(remove_stock) > 20:
            result = optimize_portfolio(expected_rets.fillna(0), factor_cov_date.fillna(0), previous_weight.loc[tradable_codes], (index_weight/index_weight.sum()).loc[tradable_codes], 
                                        target_weight=weight_target, max_turnover=0.15 + weights_optimize_df.iloc[date_index-1][remove_stock].sum() / 2)
        else:
            result = optimize_portfolio(expected_rets.fillna(0), factor_cov_date.fillna(0), previous_weight.loc[tradable_codes], (index_weight/index_weight.sum()).loc[tradable_codes], 
                                        target_weight=weight_target)
        realized_sum = result['x'][:(len(result['x']) // 3)].sum() + previous_weight.loc[non_tradable_codes].sum()
        status = result['success']
        minimize_value = result['fun']
        
    print(f'{date}, {status}, {minimize_value:.3f},  Finished, Sum of weight is: {realized_sum:.3f}')
            
    if status in [False] or np.abs(realized_sum - 1) > 1e-3:
        break
        
    weights_optimize_df.loc[date, tradable_codes] = np.array(result['x'][:(len(result['x']) // 3)]).flatten()
    weights_optimize_df.loc[date, non_tradable_codes] = previous_weight.loc[non_tradable_codes]
# Out:
# 2006-04-27 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2006-04-28 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2006-05-08 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2006-05-09 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2006-05-10 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2006-05-11 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2006-05-12 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2006-05-15 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2006-05-16 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2006-05-17 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2006-05-18 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2006-05-19 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2006-05-22 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2006-05-23 00:00:00, optimal, -0.187,  Finished, Sum of weight is: 1.000
# 2006-05-24 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2006-05-25 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2006-05-26 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2006-05-29 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2006-05-30 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2006-05-31 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2006-06-01 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2006-06-02 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2006-06-05 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2006-06-06 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2006-06-07 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2006-06-08 00:00:00, optimal, -0.029,  Finished, Sum of weight is: 1.000
# 2006-06-09 00:00:00, optimal, -0.027,  Finished, Sum of weight is: 1.000
# 2006-06-12 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2006-06-13 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2006-06-14 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2006-06-15 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2006-06-16 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 
00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2007-04-19 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2007-04-20 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-04-23 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-04-24 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-04-25 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2007-04-26 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2007-04-27 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-04-30 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2007-05-08 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-05-09 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-05-10 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-05-11 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2007-05-14 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-05-15 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-05-16 00:00:00, optimal, 0.003,  Finished, Sum of weight is: 1.000
# 2007-05-17 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-05-18 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2007-05-21 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2007-05-22 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2007-05-23 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-05-24 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-05-25 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-05-28 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2007-05-29 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2007-05-30 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-05-31 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2007-06-01 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-06-04 00:00:00, optimal, -0.026,  Finished, Sum of weight is: 1.000
# 2007-06-05 00:00:00, optimal, -0.026,  Finished, Sum of weight is: 1.000
# 2007-06-06 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2007-06-07 00:00:00, optimal, -0.033,  Finished, Sum of weight is: 1.000
# 2007-06-08 00:00:00, optimal, -0.030,  Finished, Sum of weight is: 1.000
# 2007-06-11 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2007-06-12 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-06-13 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2007-06-14 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-06-15 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-06-18 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-06-19 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2007-06-20 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-06-21 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2007-06-22 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2007-06-25 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2007-06-26 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2007-06-27 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2007-06-28 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2007-06-29 00:00:00, optimal, -0.026,  Finished, Sum of weight is: 1.000
# 2007-07-02 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2007-07-03 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2007-07-04 00:00:00, optimal, -0.027,  Finished, Sum of weight is: 1.000
# 2007-07-05 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2007-07-06 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2007-07-09 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2007-07-10 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2007-07-11 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2007-07-12 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2007-07-13 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-07-16 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-07-17 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-07-18 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-07-19 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2007-07-20 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2007-07-23 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-07-24 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-07-25 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-07-26 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-07-27 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2007-07-30 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2007-07-31 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-08-01 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-08-02 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-08-03 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2007-08-06 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-08-07 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-08-08 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2007-08-09 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-08-10 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-08-13 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2007-08-14 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2007-08-15 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2007-08-16 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-08-17 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-08-20 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2007-08-21 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-08-22 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-08-23 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2007-08-24 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-08-27 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-08-28 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2007-08-29 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2007-08-30 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2007-08-31 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2007-09-03 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-09-04 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2007-09-05 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-09-06 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2007-09-07 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-09-10 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-09-11 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-09-12 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-09-13 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-09-14 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2007-09-17 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-09-18 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-09-19 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-09-20 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-09-21 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-09-24 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-09-25 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2007-09-26 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-09-27 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2007-09-28 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-10-08 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-10-09 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-10-10 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-10-11 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-10-12 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-10-15 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-10-16 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-10-17 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2007-10-18 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2007-10-19 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2007-10-22 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2007-10-23 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2007-10-24 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2007-10-25 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2007-10-26 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2007-10-29 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2007-10-30 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-10-31 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2007-11-01 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2007-11-02 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2007-11-05 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2007-11-06 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-11-07 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2007-11-08 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2007-11-09 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2007-11-12 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2007-11-13 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-11-14 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-11-15 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-11-16 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-11-19 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-11-20 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-11-21 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2007-11-22 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2007-11-23 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2007-11-26 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2007-11-27 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2007-11-28 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-11-29 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2007-11-30 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2007-12-03 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2007-12-04 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-12-05 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-12-06 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2007-12-07 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2007-12-10 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2007-12-11 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2007-12-12 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2007-12-13 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2007-12-14 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-12-17 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2007-12-18 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2007-12-19 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2007-12-20 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2007-12-21 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2007-12-24 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2007-12-25 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2007-12-26 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2007-12-27 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2007-12-28 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2008-01-02 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-01-03 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2008-01-04 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2008-01-07 00:00:00, optimal, -0.002,  Finished, Sum of weight is: 1.000
# 2008-01-08 00:00:00, optimal, 0.000,  Finished, Sum of weight is: 1.000
# 2008-01-09 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2008-01-10 00:00:00, optimal, 0.003,  Finished, Sum of weight is: 1.000
# 2008-01-11 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2008-01-14 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2008-01-15 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-01-16 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-01-17 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2008-01-18 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-01-21 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-01-22 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-01-23 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-01-24 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-01-25 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-01-28 00:00:00, optimal, -0.027,  Finished, Sum of weight is: 1.000
# 2008-01-29 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-01-30 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-01-31 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-02-01 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2008-02-04 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-02-05 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-02-13 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-02-14 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-02-15 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2008-02-18 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-02-19 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-02-20 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-02-21 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2008-02-22 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-02-25 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-02-26 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-02-27 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-02-28 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-02-29 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2008-03-03 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-03-04 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2008-03-05 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-03-06 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-03-07 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2008-03-10 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-03-11 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-03-12 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2008-03-13 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2008-03-14 00:00:00, optimal, -0.028,  Finished, Sum of weight is: 1.000
# 2008-03-17 00:00:00, optimal, -0.035,  Finished, Sum of weight is: 1.000
# 2008-03-18 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-03-19 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-03-20 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-03-21 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-03-24 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-03-25 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-03-26 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-03-27 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-03-28 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-03-31 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-04-01 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-04-02 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-04-03 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-04-07 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-04-08 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-04-09 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-04-10 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-04-11 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-04-14 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-04-15 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-04-16 00:00:00, optimal, -0.023,  Finished, Sum of weight is: 1.000
# 2008-04-17 00:00:00, optimal, -0.026,  Finished, Sum of weight is: 1.000
# 2008-04-18 00:00:00, optimal, -0.027,  Finished, Sum of weight is: 1.000
# 2008-04-21 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2008-04-22 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-04-23 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-04-24 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2008-04-25 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-04-28 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-04-29 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-04-30 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2008-05-05 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-05-06 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-05-07 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-05-08 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-05-09 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-05-12 00:00:00, optimal, -0.023,  Finished, Sum of weight is: 1.000
# 2008-05-13 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-05-14 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2008-05-15 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2008-05-16 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-05-19 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-05-20 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-05-21 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-05-22 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-05-23 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2008-05-26 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-05-27 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-05-28 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-05-29 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-05-30 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-06-02 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-06-03 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-06-04 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-06-05 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-06-06 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-06-10 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-06-11 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-06-12 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-06-13 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-06-16 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-06-17 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-06-18 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2008-06-19 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-06-20 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-06-23 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-06-24 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-06-25 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-06-26 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-06-27 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-06-30 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-07-01 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-07-02 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-07-03 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-07-04 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-07-07 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-07-08 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-07-09 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-07-10 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-07-11 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-07-14 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-07-15 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-07-16 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2008-07-17 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-07-18 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-07-21 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-07-22 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-07-23 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-07-24 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-07-25 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-07-28 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-07-29 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-07-30 00:00:00, optimal, -0.027,  Finished, Sum of weight is: 1.000
# 2008-07-31 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-08-01 00:00:00, optimal, -0.028,  Finished, Sum of weight is: 1.000
# 2008-08-04 00:00:00, optimal, -0.028,  Finished, Sum of weight is: 1.000
# 2008-08-05 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-08-06 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-08-07 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-08-08 00:00:00, optimal, -0.023,  Finished, Sum of weight is: 1.000
# 2008-08-11 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-08-12 00:00:00, optimal, -0.023,  Finished, Sum of weight is: 1.000
# 2008-08-13 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-08-14 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-08-15 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-08-18 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-08-19 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-08-20 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-08-21 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2008-08-22 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-08-25 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-08-26 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-08-27 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-08-28 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-08-29 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-09-01 00:00:00, optimal, -0.015,  Finished, Sum of weight is: 1.000
# 2008-09-02 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-09-03 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-09-04 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-09-05 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-09-08 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2008-09-09 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2008-09-10 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-09-11 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-09-12 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-09-16 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-09-17 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-09-18 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-09-19 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-09-22 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2008-09-23 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-09-24 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-09-25 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-09-26 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-10-06 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-10-07 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-10-08 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2008-10-09 00:00:00, optimal, -0.023,  Finished, Sum of weight is: 1.000
# 2008-10-10 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-10-13 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-10-14 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-10-15 00:00:00, optimal, -0.026,  Finished, Sum of weight is: 1.000
# 2008-10-16 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2008-10-17 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-10-20 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-10-21 00:00:00, optimal, -0.020,  Finished, Sum of weight is: 1.000
# 2008-10-22 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-10-23 00:00:00, optimal, -0.019,  Finished, Sum of weight is: 1.000
# 2008-10-24 00:00:00, optimal, -0.026,  Finished, Sum of weight is: 1.000
# 2008-10-27 00:00:00, optimal, -0.027,  Finished, Sum of weight is: 1.000
# 2008-10-28 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-10-29 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-10-30 00:00:00, optimal, -0.024,  Finished, Sum of weight is: 1.000
# 2008-10-31 00:00:00, optimal, -0.022,  Finished, Sum of weight is: 1.000
# 2008-11-03 00:00:00, optimal, -0.025,  Finished, Sum of weight is: 1.000
# 2008-11-04 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-11-05 00:00:00, optimal, -0.017,  Finished, Sum of weight is: 1.000
# 2008-11-06 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2008-11-07 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2008-11-10 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-11-11 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-11-12 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2008-11-13 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-11-14 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2008-11-17 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-11-18 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2008-11-19 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2008-11-20 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-11-21 00:00:00, optimal, -0.035,  Finished, Sum of weight is: 1.000
# 2008-11-24 00:00:00, optimal, -0.021,  Finished, Sum of weight is: 1.000
# 2008-11-25 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-11-26 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-11-27 00:00:00, optimal, -0.018,  Finished, Sum of weight is: 1.000
# 2008-11-28 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-12-01 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2008-12-02 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2008-12-03 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-12-04 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-12-05 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-12-08 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-12-09 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2008-12-10 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-12-11 00:00:00, optimal, -0.016,  Finished, Sum of weight is: 1.000
# 2008-12-12 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-12-15 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2008-12-16 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# 2008-12-17 00:00:00, optimal, -0.001,  Finished, Sum of weight is: 1.000
# 2008-12-18 00:00:00, optimal, -0.000,  Finished, Sum of weight is: 1.000
# 2008-12-19 00:00:00, optimal, 0.001,  Finished, Sum of weight is: 1.000
# 2008-12-22 00:00:00, optimal, -0.005,  Finished, Sum of weight is: 1.000
# 2008-12-23 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2008-12-24 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2008-12-25 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2008-12-26 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2008-12-29 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2008-12-30 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2008-12-31 00:00:00, optimal, -0.007,  Finished, Sum of weight is: 1.000
# 2009-01-05 00:00:00, optimal, -0.003,  Finished, Sum of weight is: 1.000
# 2009-01-06 00:00:00, optimal, 0.002,  Finished, Sum of weight is: 1.000
# 2009-01-07 00:00:00, optimal, -0.004,  Finished, Sum of weight is: 1.000
# ...
# 2022-09-08 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2022-09-09 00:00:00, optimal, -0.006,  Finished, Sum of weight is: 1.000
# 2022-09-13 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2022-09-14 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2022-09-15 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2022-09-16 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-09-19 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-09-20 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-09-21 00:00:00, optimal, -0.013,  Finished, Sum of weight is: 1.000
# 2022-09-22 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-09-23 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-09-26 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2022-09-27 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2022-09-28 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-09-29 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2022-09-30 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2022-10-10 00:00:00, optimal, -0.156,  Finished, Sum of weight is: 1.000
# 2022-10-11 00:00:00, optimal, -0.012,  Finished, Sum of weight is: 1.000
# 2022-10-12 00:00:00, optimal, -0.014,  Finished, Sum of weight is: 1.000
# 2022-10-13 00:00:00, optimal, -0.008,  Finished, Sum of weight is: 1.000
# 2022-10-14 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 2022-10-17 00:00:00, optimal, -0.010,  Finished, Sum of weight is: 1.000
# 2022-10-18 00:00:00, optimal, -0.011,  Finished, Sum of weight is: 1.000
# 2022-10-19 00:00:00, optimal, -0.009,  Finished, Sum of weight is: 1.000
# 